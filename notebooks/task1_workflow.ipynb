# %% [markdown]
# # Task 1 Workflow

# %%
# 选择kernel的时候使用刚刚使用uv创建的虚拟环境
# 如果更改来代码发现notebook的结果没有更新, 可以尝试点击重启kernel
from pathlib import Path
import sys

import pandas as pd
from IPython.display import Markdown, display

repo_root = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))

from src.task1_cleaning.pipeline import run_task1_cleaning
from src.task1_statistics.pipeline import run_all_task1_statistics

# 这里如果改了csv的文件名, 这里也要修改
raw_data_path = repo_root / "data" / "raw" / "raw_data.csv" 
cleaned_data_path = repo_root / "data" / "processed" / "cleaned_data.csv"
statistics_output_path = repo_root / "data" / "statistics" / "statistics_output.csv"

# %% [markdown]
# ## Raw Data

# %%
raw_df = pd.read_csv(raw_data_path)
display(raw_df.head())

# %% [markdown]
# ## Cleaned Data

# %%
cleaned_df = run_task1_cleaning(raw_data_path, cleaned_data_path)
display(cleaned_df.head())

# %% [markdown]
# ## Statistics

# %%
statistics_df = run_all_task1_statistics(cleaned_df)
statistics_output_path.parent.mkdir(parents=True, exist_ok=True)
statistics_df.to_csv(statistics_output_path, index=False)
display(statistics_df)

# %% [markdown]
# ## Markdown Table

# %%
# 推荐默认使用display方法来直接展示dataframe
# 需要的话也可以再转换为markdown格式的表格来展示
display(Markdown(statistics_df.to_markdown(index=False)))
